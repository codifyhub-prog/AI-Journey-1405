# %%
age =int(input("enter your age"))
if age >=18:
    print("Ok")
else:
    print("No")
# Out:
# enter your age 20
# Ok

# %%
num=int(input("enter a number"))
if num >0:
    print("positive")
elif num<0:
    print("negative")
else:
    print("0")
# Out:
# enter a number -10
# negative

# %%
num1=int(input("enter first number"))
num2=int(input("enter second number"))
num3=int(input("enter third number"))
maximum=num1
if num2>= maximum:
    maximum=num2
if num3>=maximum:
    maximum=num3
print(maximum)
# Out:
# enter first number 14
# enter second number 13
# enter third number 12
# 14

# %%
score=float(input("enter your score"))
if score>=10:
    print("pass")
else:
    print("failed")
# Out:
# enter your score 9.993
# failed

# %%
name="admin"
password=1234
yname=input("enter your name")
ypassword=int(input("enter your password"))
if (name==yname) and (password==ypassword):
    print("login successful")
else:
    print("error")
